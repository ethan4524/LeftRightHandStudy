# %%
import pandas as pd
import matplotlib.pyplot as plt

logger_data_df = pd.read_csv('logger_data.csv')
logger_data_df['Row'] = range(1, len(logger_data_df) + 1)

# Filter data for a specific player (e.g., playerID = 'b1a54a67-ec21-4958-af34-2352bdbe3f10')
player_id = '2cd06449-375f-4467-abc7-68b80c00abf3'
player_data = logger_data_df[logger_data_df['playerID'] == player_id]
player_data = player_data.head(1000)

# Plot left and right hand y positions over time for the selected player
plt.figure(figsize=(20, 6))
plt.plot(player_data['Row'], player_data['leftHandPos_y'], label='Left Hand', linestyle='-', marker='o')
plt.plot(player_data['Row'], player_data['rightHandPos_y'], label='Right Hand', linestyle='--', marker='x')

plt.xlabel('Row')
plt.ylabel('Y Position')
plt.title(f'Left and Right Hand Y Positions Over Rows for Player {player_id}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


logger_data_df = pd.read_csv('logger_data.csv')
logger_data_df['Row'] = range(1, len(logger_data_df) + 1)

# Filter data for a specific player (e.g., playerID = 'b1a54a67-ec21-4958-af34-2352bdbe3f10')
player_id = 'b1a54a67-ec21-4958-af34-2352bdbe3f10'
player_data = logger_data_df[logger_data_df['playerID'] == player_id]
player_data = player_data.head(1000)

# Plot left and right hand y positions over time for the selected player
plt.figure(figsize=(20, 6))
plt.plot(player_data['Row'], player_data['leftHandPos_y'], label='Left Hand', linestyle='-', marker='o')
plt.plot(player_data['Row'], player_data['rightHandPos_y'], label='Right Hand', linestyle='--', marker='x')

plt.xlabel('Row')
plt.ylabel('Y Position')
plt.title(f'Left and Right Hand Y Positions Over Rows for Player {player_id}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
logger_data_df['playerID'].unique()
# Out:
# array(['b1a54a67-ec21-4958-af34-2352bdbe3f10',
#        '2cd06449-375f-4467-abc7-68b80c00abf3',
#        'fe6db3f7-524d-49d2-9e82-f6925af05931'], dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt

logger_data_df = pd.read_csv('logger_data.csv')
logger_data_df['Row'] = range(1, len(logger_data_df) + 1)

# Filter data for a specific player (e.g., playerID = 'b1a54a67-ec21-4958-af34-2352bdbe3f10')
player_id = 'b1a54a67-ec21-4958-af34-2352bdbe3f10'
player_data = logger_data_df[logger_data_df['playerID'] == player_id]
player_data = player_data.head(1000)

# Plot left and right hand y positions over time for the selected player
plt.figure(figsize=(20, 6))
plt.plot(player_data['Row'], player_data['leftHandPos_y'], label='Left Hand', linestyle='-', marker='o')
#plt.plot(player_data['Row'], player_data['rightHandPos_y'], label='Right Hand', linestyle='--', marker='x')

plt.xlabel('Row')
plt.ylabel('Y Position')
plt.title(f'Left and Right Hand Y Positions Over Rows for Player {player_id}')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Read the CSV file into a DataFrame
logger_data_df = pd.read_csv('logger_data.csv')

# Convert timeStamp column to datetime format
logger_data_df['timeStamp'] = pd.to_datetime(logger_data_df['timeStamp'])

# Filter data for a specific player (e.g., playerID = 'b1a54a67-ec21-4958-af34-2352bdbe3f10')
player_id = 'b1a54a67-ec21-4958-af34-2352bdbe3f10'
player_data = logger_data_df[logger_data_df['playerID'] == player_id]
player_data = player_data.iloc[2100:2300]

# Create a 3D plot
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111, projection='3d')

# Plot left hand and right hand positions over time for the selected player
#ax.plot(range(len(player_data)), player_data['leftHandPos_z'], player_data['leftHandPos_y'], label='Left Hand')
#ax.plot(range(len(player_data)), player_data['rightHandPos_z'], player_data['rightHandPos_y'], label='Right Hand')
# Assuming player_data is a DataFrame containing the data
# You may need to adjust the column names based on your actual DataFrame structure
player_data['leftHandMoment_x'] = player_data['leftHandMoment'].apply(lambda moment: moment.x)
player_data['leftHandMoment_y'] = player_data['leftHandMoment'].apply(lambda moment: moment.y)
player_data['leftHandMoment_z'] = player_data['leftHandMoment'].apply(lambda moment: moment.z)
# Plot left hand and right hand positions over time for the selected player
ax.plot(range(len(player_data)), player_data['leftHandPos_z'], player_data['leftHandPos_y'], label='Left Hand')
ax.plot(range(len(player_data)), player_data['rightHandPos_z'], player_data['rightHandPos_y'], label='Right Hand')


ax.set_xlabel('Time (60 samples = 1 sec)')
ax.set_ylabel('Z Position')
ax.set_zlabel('Y Position')
ax.set_title(f'Left and Right Hand Positions Over Time for Player {player_id}')
ax.legend()

plt.show()
# Out:
# C:\Users\Ethan\AppData\Local\Temp\ipykernel_61092\1682269782.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   logger_data_df['timeStamp'] = pd.to_datetime(logger_data_df['timeStamp'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Ethan\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
